# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# We load the dataset
house_data_raw = pd.read_csv('house.csv')
house_data = house_data_raw[house_data_raw['loyer'] < 7000]
# We display the cloud of points that we have
fig = plt.figure(figsize=(10,8))
plt.plot(house_data['surface'], house_data['loyer'], 'mo', markersize=4)
plt.style.use(plt.style.available[5])
plt.show()

# %%
# We break down the dataset and transform it into matrices so we can perform our calculation
X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].values]).T
y = np.matrix(house_data['loyer']).T

# Exact calculation of theta parameter (Normal Equation)
theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)
print(theta)
# Out:
# [[359.52266178]
#  [ 28.6687785 ]]

# %%
fig = plt.figure(figsize=(10,8))
plt.xlabel('Surface')
plt.ylabel('Loyer')
plt.plot(house_data['surface'], house_data['loyer'], 'ro', markersize=4)

# We display the line between 0 and 250
plt.plot([0,250], [theta.item(0) + 0 * theta.item(1) ,theta.item(0) + 250 * theta.item(1)], linestyle='--', c='#000000')
plt.style.use(plt.style.available[5])
plt.show()
